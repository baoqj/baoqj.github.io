# %% [markdown]
# <a href="https://colab.research.google.com/github/baoqj/baoqj.github.io/blob/main/chattts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/2noise/ChatTTS
# !mv ChatTTS abc
# !mv abc/* .
# Out:
# Cloning into 'ChatTTS'...
# remote: Enumerating objects: 2482, done.
# remote: Counting objects: 100% (563/563), done.
# remote: Compressing objects: 100% (298/298), done.
# remote: Total 2482 (delta 327), reused 355 (delta 263), pack-reused 1919 (from 1)
# Receiving objects: 100% (2482/2482), 7.96 MiB | 6.67 MiB/s, done.
# Resolving deltas: 100% (1490/1490), done.

# %%
# !cat ChatTTS/__init__.py
# !pip install omegaconf
# !pip install vocos
# !pip install vector_quantize_pytorch
# Out:
# from .core import Chat
# ...

# %%
# !pip install ChatTTS
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.8/114.8 kB 10.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.5/352.5 kB 24.0 MB/s eta 0:00:00
# ...
#   Created wheel for ChatTTS: filename=chattts-0.1.1-py3-none-any.whl size=125023 sha256=ed21e64751babfc999ebe4e20e81ebbb4da1d809077b40f4c6a1150d5fa289c8
#   Stored in directory: /root/.cache/pip/wheels/59/8e/27/147507c3d94b4aee58ab16ebe6562aade8776f75d87da4aad5
# Successfully built ChatTTS
# ...

# %%
import torch
from ChatTTS.core import Chat
from IPython.display import Audio
import ChatTTS
import torchaudio

chat = Chat()
chat.load()
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# True

# %%
texts = ["So we found being competitive and collaborative was a huge way of "
 "staying motivated towards our goals, so one person to call when you fall off"
"one person who gets you back on then one person to actually do the activity with.",]*3 \
        + ["我觉得像我们这些写程序的人，他，我觉得多多少少可能会对开源有一种情怀在吧我觉得开源是一个很好的形式。现在其实最先进的技术掌握在一些公司的手里的话，就他们并不会轻易的开放给所有的人用。"]*3 \
                + ["以下音频是我刚用程序生成的，大家感受下 TTS 现在进步到什么程度了。试用了一下 ChatTTS 有点牛逼大家感受下有多牛逼。他那个文档和接口有点粗糙，需要不少自己写的地方。"]*3

# texts=["以下音频是我刚用程序生成的，大家感受下 TTS 现在进步到什么程度了。试用了一下 ChatTTS 有点牛逼大家感受下有多牛逼。他那个文档和接口有点粗糙，需要不少自己写的地方。"]
wavs = chat.infer(texts, use_decoder=True)
# Out:
# text:   0%|          | 0/384(max) [00:00, ?it/s]We detected that you are passing `past_key_values` as a tuple and this is deprecated and will be removed in v4.43. Please use an appropriate `Cache` class (https://huggingface.co/docs/transformers/v4.41.3/en/internal/generation_utils#transformers.Cache)
# text:  29%|██▊       | 110/384(max) [00:04, 27.29it/s]
# code:  44%|████▍     | 902/2048(max) [00:28, 31.53it/s]

# %%
from IPython.display import Audio

# %%
Audio(wavs[3], rate=24_000, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(wavs[7], rate=24_000, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
